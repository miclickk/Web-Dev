# %%
a=int(input())
b=int(input())

if (a<b):
    print(b)
else:
    print(a)
# Out:
# 2

# %%
year = int(input())

if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print("YES")
else:
    print("NO")

# %%
a = int(input())
b = int(input())

if (a == 1 and b == 1) or (a != 1 and b != 1):
    print("YES")
else:
    print("NO")

# %%
x = int(input())

if x > 0:
    print(1)
elif x < 0:
    print(-1)
else:
    print(0)

# %%
a=int(input())
b=int(input())

if (a<b):
    print(2)
elif (a>b):
    print(1)
else:
    print(0)
